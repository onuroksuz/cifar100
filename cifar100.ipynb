# %%
import tensorflow
import tensorflow as tf
import keras
import os 
from PIL import Image
import matplotlib.pyplot as plt
from keras.datasets import cifar100
import numpy as np
import cv2
from tqdm import tqdm
import random

(X_train, y_train),(X_test, y_test)=cifar100.load_data()

os.mkdir('C:\\Users\\onuro\\Desktop\\dataset')
os.mkdir('C:\\Users\\onuro\\Desktop\\dataset\\train')
os.mkdir('C:\\Users\\onuro\\Desktop\\dataset\\test')


for i in range(100):
    if(i==11):
        path=os.path.join('C:\\Users\\onuro\\Desktop\\dataset\\train', 'boy')
        os.mkdir(path)
        path=os.path.join('C:\\Users\\onuro\\Desktop\\dataset\\test', 'boy')
        os.mkdir(path)
    if(i==44):
        path=os.path.join('C:\\Users\\onuro\\Desktop\\dataset\\train', 'lizard')
        os.mkdir(path)
        path=os.path.join('C:\\Users\\onuro\\Desktop\\dataset\\test', 'lizard')
        os.mkdir(path)
    if(i==65):
        path=os.path.join('C:\\Users\\onuro\\Desktop\\dataset\\train', 'rabbit')
        os.mkdir(path)
        path=os.path.join('C:\\Users\\onuro\\Desktop\\dataset\\test', 'rabbit')
        os.mkdir(path)
    if(i==78):
        path=os.path.join('C:\\Users\\onuro\\Desktop\\dataset\\train', 'snake')
        os.mkdir(path)
        path=os.path.join('C:\\Users\\onuro\\Desktop\\dataset\\test', 'snake')
        os.mkdir(path)
    if(i==88):
        path=os.path.join('C:\\Users\\onuro\\Desktop\\dataset\\train', 'tiger')
        os.mkdir(path)
        path=os.path.join('C:\\Users\\onuro\\Desktop\\dataset\\test', 'tiger')
        os.mkdir(path) 
    if(i==93):
        path=os.path.join('C:\\Users\\onuro\\Desktop\\dataset\\train', 'turtle')
        os.mkdir(path)
        path=os.path.join('C:\\Users\\onuro\\Desktop\\dataset\\test', 'turtle')
        os.mkdir(path)

# %%
for i in range(50000):
    if(y_train[i]==11):
        path='C:\\Users\\onuro\\Desktop\\dataset\\train\\boy'+'/'+str(i)+ '.png'
        train_data=Image.fromarray(X_train[i])
        plt.imsave(path, X_train[i])
    if(y_train[i]==44):
        path='C:\\Users\\onuro\\Desktop\\dataset\\train\\lizard'+'/'+str(i)+ '.png'
        train_data=Image.fromarray(X_train[i])
        plt.imsave(path, X_train[i])
    if(y_train[i]==65):
        path='C:\\Users\\onuro\\Desktop\\dataset\\train\\rabbit'+'/'+str(i)+ '.png'
        train_data=Image.fromarray(X_train[i])
        plt.imsave(path, X_train[i])
    if(y_train[i]==78):
        path='C:\\Users\\onuro\\Desktop\\dataset\\train\\snake'+'/'+str(i)+ '.png'
        train_data=Image.fromarray(X_train[i])
        plt.imsave(path, X_train[i])
    if(y_train[i]==88):
        path='C:\\Users\\onuro\\Desktop\\dataset\\train\\tiger'+'/'+str(i)+ '.png'
        train_data=Image.fromarray(X_train[i])
        plt.imsave(path, X_train[i])    
    if(y_train[i]==93):
        path='C:\\Users\\onuro\\Desktop\\dataset\\train\\turtle'+'/'+str(i)+ '.png'
        train_data=Image.fromarray(X_train[i])
        plt.imsave(path, X_train[i])

# %%
for i in range(10000):
    if(y_test[i]==11):
        path='C:\\Users\\onuro\\Desktop\\dataset\\test\\boy'+'/'+str(i)+ '.png'
        test_data=Image.fromarray(X_test[i])
        plt.imsave(path, X_test[i])
    if(y_test[i]==44):
        path='C:\\Users\\onuro\\Desktop\\dataset\\test\\lizard'+'/'+str(i)+ '.png'
        test_data=Image.fromarray(X_test[i])
        plt.imsave(path, X_test[i])
    if(y_test[i]==65):
        path='C:\\Users\\onuro\\Desktop\\dataset\\test\\rabbit'+'/'+str(i)+ '.png'
        test_data=Image.fromarray(X_test[i])
        plt.imsave(path, X_test[i])
    if(y_test[i]==78):
        path='C:\\Users\\onuro\\Desktop\\dataset\\test\\snake'+'/'+str(i)+ '.png'
        test_data=Image.fromarray(X_test[i])
        plt.imsave(path, X_test[i])
    if(y_test[i]==88):
        path='C:\\Users\\onuro\\Desktop\\dataset\\test\\tiger'+'/'+str(i)+ '.png'
        test_data=Image.fromarray(X_test[i])
        plt.imsave(path, X_test[i])    
    if(y_test[i]==93):
        path='C:\\Users\\onuro\\Desktop\\dataset\\test\\turtle'+'/'+str(i)+ '.png'
        test_data=Image.fromarray(X_test[i])
        plt.imsave(path, X_test[i])

# %%
TRAIN_DIR = "C:\\Users\\onuro\\Desktop\\dataset\\train"
TEST_DIR = "C:\\Users\\onuro\\Desktop\\dataset\\test"
CATEGORIES = ["boy", "lizard", "rabbit", "snake", "tiger", "turtle"]
CATEGORIES_2 =  ["boy", "lizard", "rabbit", "snake", "tiger", "turtle"]
        
def label_img(img):
    word_label = img.split('.')[-1]
    if word_label == '1': return 1
    elif word_label == '2': return 2
    elif word_label == '3': return 3
    elif word_label == '4': return 4
    elif word_label == '5': return 5
    elif word_label == '6': return 6

# %%
from tqdm import tqdm
import random
import numpy as np
import os
import cv2
def create_training_data():
    training_data = []
    
    for category in CATEGORIES:                  
        path = os.path.join(TRAIN_DIR,category)  
        class_num = CATEGORIES.index(category)  
        for img in tqdm(os.listdir(path)):  
            label = label_img(img)          
            try:                 
                img_array = cv2.imread(os.path.join(path,img))            
                training_data.append([np.array(img_array), np.array(class_num)])        
            except Exception as e:  
                pass
    random.shuffle(training_data)              
    np.save('train_data.npy', training_data)   
    return training_data
    
train_data=create_training_data()      
print(len(train_data))
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 1142.57it/s]
# 100%|██████████| 500/500 [00:00<00:00, 910.03it/s]
# 100%|██████████| 500/500 [00:00<00:00, 1058.39it/s]
# 100%|██████████| 500/500 [00:00<00:00, 884.80it/s]
# 100%|██████████| 500/500 [00:00<00:00, 815.64it/s]
# 100%|██████████| 500/500 [00:00<00:00, 834.78it/s]
# 3000

# %%
def create_test_data():
    testing_data = []
    for category_2 in CATEGORIES_2:       
        path = os.path.join(TEST_DIR,category_2)
        class_num=CATEGORIES_2.index(category_2)        
        for img in tqdm(os.listdir(path)):
            label = label_img(img)         
            try:
                img_array = cv2.imread(os.path.join(path,img))
                testing_data.append([np.array(img_array), class_num])        
            except Exception as e:
                pass           
    random.shuffle(testing_data) 
    np.save('test_data.npy', testing_data)    
    return testing_data    

test_data=create_test_data()

print(len(test_data))
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 1010.11it/s]
# 100%|██████████| 100/100 [00:00<00:00, 1246.58it/s]
# 100%|██████████| 100/100 [00:00<00:00, 1275.53it/s]
# 100%|██████████| 100/100 [00:00<00:00, 1195.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 1323.26it/s]
# 100%|██████████| 100/100 [00:00<00:00, 887.27it/s]
# 600

# %%
import keras
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D

model = Sequential()
model.add(Conv2D(16, (3, 3), padding='same'))  #convNet 1
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))                  #covNet  2
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))                  #covNet  3
model.add(MaxPooling2D(pool_size=(2, 2)))      #Maxpool I
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))                  #covNet  4
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))                 #covNet  5
model.add(Activation('relu'))    
model.add(MaxPooling2D(pool_size=(2, 2)))      #Maxpool II
model.add(Conv2D(128, (3, 3)))                 #covNet  6
model.add(Activation('relu'))       
model.add(MaxPooling2D(pool_size=(2, 2)))      #Maxpool III

model.add(Flatten())                            #Flatten#
model.add(Dense(128))                           #Dense 1
model.add(Activation('relu'))
model.add(Dense(256))                           #Dense 2
model.add(Activation('relu'))

model.add(Dense(6, activation='softmax'))       #Dense 3

opt = keras.optimizers.RMSprop(learning_rate=0.00001, decay=1e-6)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt,
              metrics=['acc'])

# %%
import numpy as np
X = np.array([i[0] for i in train_data]).reshape(-1,32,32,3)
Y = [i[1] for i in train_data]
Y = np.reshape(Y, (-1, 1))

X_test = np.array([i[0] for i in test_data]).reshape(-1,32,32,3)
Y_test = [i[1] for i in test_data]
Y_test = np.reshape(Y_test, (-1, 1))

history=model.fit(X, Y, epochs=16,
          batch_size=50, validation_data = (X_test, Y_test), shuffle=True)
# Out:
# Train on 3000 samples, validate on 600 samples
# Epoch 1/16
# 3000/3000 [==============================] - 20s 7ms/step - loss: 2.7866 - acc: 0.1843 - val_loss: 1.8941 - val_acc: 0.2200
# Epoch 2/16
# 3000/3000 [==============================] - 19s 6ms/step - loss: 1.8016 - acc: 0.2480 - val_loss: 1.7522 - val_acc: 0.2733
# Epoch 3/16
# 3000/3000 [==============================] - 19s 6ms/step - loss: 1.7043 - acc: 0.2970 - val_loss: 1.6825 - val_acc: 0.2983
# Epoch 4/16
# 3000/3000 [==============================] - 19s 6ms/step - loss: 1.6352 - acc: 0.3207 - val_loss: 1.6679 - val_acc: 0.3233
# Epoch 5/16
# 3000/3000 [==============================] - 19s 6ms/step - loss: 1.5899 - acc: 0.3577 - val_loss: 1.6205 - val_acc: 0.3317
# Epoch 6/16
# 3000/3000 [==============================] - 19s 6ms/step - loss: 1.5611 - acc: 0.3633 - val_loss: 1.6071 - val_acc: 0.3433
# Epoch 7/16
# 3000/3000 [==============================] - 20s 7ms/step - loss: 1.5229 - acc: 0.3833 - val_loss: 1.5965 - val_acc: 0.3383
# Epoch 8/16
# 3000/3000 [==============================] - 19s 6ms/step - loss: 1.5000 - acc: 0.3847 - val_loss: 1.5520 - val_acc: 0.3800
# Epoch 9/16
# 3000/3000 [==============================] - 19s 6ms/step - loss: 1.4741 - acc: 0.4120 - val_loss: 1.5516 - val_acc: 0.3767
# Epoch 10/16
# 3000/3000 [==============================] - 19s 6ms/step - loss: 1.4521 - acc: 0.4217 - val_loss: 1.5335 - val_acc: 0.3833
# Epoch 11/16
# 3000/3000 [==============================] - 19s 6ms/step - loss: 1.4339 - acc: 0.4340 - val_loss: 1.5244 - val_acc: 0.3783
# Epoch 12/16
# 3000/3000 [==============================] - 20s 7ms/step - loss: 1.4102 - acc: 0.4440 - val_loss: 1.5011 - val_acc: 0.4250
# Epoch 13/16
# 3000/3000 [==============================] - 20s 7ms/step - loss: 1.3951 - acc: 0.4527 - val_loss: 1.4867 - val_acc: 0.4183
# Epoch 14/16
# 3000/3000 [==============================] - 19s 6ms/step - loss: 1.3765 - acc: 0.4557 - val_loss: 1.5733 - val_acc: 0.3583
# Epoch 15/16
# 3000/3000 [==============================] - 20s 7ms/step - loss: 1.3622 - acc: 0.4707 - val_loss: 1.5090 - val_acc: 0.4133
# Epoch 16/16
# 3000/3000 [==============================] - 19s 6ms/step - loss: 1.3396 - acc: 0.4827 - val_loss: 1.4562 - val_acc: 0.4400

# %%
import matplotlib.pyplot as plt
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen=ImageDataGenerator(
    zoom_range=0.2,
    horizontal_flip=True)

datagen.fit(X)
history=model.fit_generator(datagen.flow(X,Y, batch_size=100),
                   epochs=16,
                   validation_data=(X_test, Y_test))
# Out:
# Epoch 1/16
# 30/30 [==============================] - 19s 645ms/step - loss: 1.4271 - acc: 0.4360 - val_loss: 1.5207 - val_acc: 0.4017
# Epoch 2/16
# 30/30 [==============================] - 19s 622ms/step - loss: 1.4221 - acc: 0.4273 - val_loss: 1.4981 - val_acc: 0.3983
# Epoch 3/16
# 30/30 [==============================] - 18s 613ms/step - loss: 1.4094 - acc: 0.4400 - val_loss: 1.4337 - val_acc: 0.4567
# Epoch 4/16
# 30/30 [==============================] - 18s 611ms/step - loss: 1.4015 - acc: 0.4527 - val_loss: 1.4350 - val_acc: 0.4467
# Epoch 5/16
# 30/30 [==============================] - 18s 615ms/step - loss: 1.3799 - acc: 0.4587 - val_loss: 1.4311 - val_acc: 0.4633
# Epoch 6/16
# 30/30 [==============================] - 19s 623ms/step - loss: 1.3896 - acc: 0.4580 - val_loss: 1.4253 - val_acc: 0.4667
# Epoch 7/16
# 30/30 [==============================] - 24s 810ms/step - loss: 1.3834 - acc: 0.4610 - val_loss: 1.4059 - val_acc: 0.4567
# Epoch 8/16
# 30/30 [==============================] - 21s 697ms/step - loss: 1.3854 - acc: 0.4527 - val_loss: 1.4038 - val_acc: 0.4667
# Epoch 9/16
# 30/30 [==============================] - 21s 712ms/step - loss: 1.3720 - acc: 0.4683 - val_loss: 1.4706 - val_acc: 0.4233
# Epoch 10/16
# 30/30 [==============================] - 19s 621ms/step - loss: 1.3715 - acc: 0.4503 - val_loss: 1.4202 - val_acc: 0.4433
# Epoch 11/16
# 30/30 [==============================] - 18s 613ms/step - loss: 1.3560 - acc: 0.4753 - val_loss: 1.4100 - val_acc: 0.4517
# Epoch 12/16
# 30/30 [==============================] - 18s 610ms/step - loss: 1.3513 - acc: 0.4737 - val_loss: 1.4251 - val_acc: 0.4533
# Epoch 13/16
# 30/30 [==============================] - 18s 611ms/step - loss: 1.3525 - acc: 0.4673 - val_loss: 1.4699 - val_acc: 0.4250
# Epoch 14/16
# 30/30 [==============================] - 19s 619ms/step - loss: 1.3328 - acc: 0.4730 - val_loss: 1.3868 - val_acc: 0.4733
# Epoch 15/16
# 30/30 [==============================] - 18s 616ms/step - loss: 1.3292 - acc: 0.4897 - val_loss: 1.3734 - val_acc: 0.4850
# Epoch 16/16
# 30/30 [==============================] - 18s 608ms/step - loss: 1.3344 - acc: 0.4853 - val_loss: 1.3797 - val_acc: 0.4767

# %%
import matplotlib.pyplot as plt
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
import keras
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D

model = Sequential()
model.add(Conv2D(16, (3, 3), padding='same'))  #convNet 1
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))                  #covNet  2
model.add(Activation('relu'))
model.add(Dropout(0.15))                       #Dropout I
model.add(Conv2D(64, (3, 3)))                  #covNet  3
model.add(MaxPooling2D(pool_size=(2, 2)))      #Maxpool I
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))                  #covNet  4
model.add(Activation('relu'))
model.add(Dropout(0.25))                       #Dropout II
model.add(Conv2D(128, (3, 3)))                 #covNet  5
model.add(Activation('relu'))    
model.add(MaxPooling2D(pool_size=(2, 2)))      #Maxpool II
model.add(Conv2D(128, (3, 3)))                 #covNet  6
model.add(Activation('relu'))       
model.add(MaxPooling2D(pool_size=(2, 2)))      #Maxpool III

model.add(Flatten())                           #Flatten#
model.add(Dense(128))                          #Dense 1
model.add(Activation('relu'))
model.add(Dense(256))                          #Dense 2
model.add(Activation('relu'))

model.add(Dense(6, activation='softmax'))      #Dense 3

opt = keras.optimizers.RMSprop(learning_rate=0.00001, decay=1e-6)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt,
              metrics=['acc'])

# %%
import numpy as np
X = np.array([i[0] for i in train_data]).reshape(-1,32,32,3)
Y = [i[1] for i in train_data]
Y = np.reshape(Y, (-1, 1))

X_test = np.array([i[0] for i in test_data]).reshape(-1,32,32,3)
Y_test = [i[1] for i in test_data]
Y_test = np.reshape(Y_test, (-1, 1))

history=model.fit(X, Y, epochs=16,
          batch_size=50, validation_data = (X_test, Y_test), shuffle=True)
# Out:
# Train on 3000 samples, validate on 600 samples
# Epoch 1/16
# 3000/3000 [==============================] - 26s 9ms/step - loss: 2.8311 - acc: 0.1733 - val_loss: 1.8771 - val_acc: 0.1567
# Epoch 2/16
# 3000/3000 [==============================] - 30s 10ms/step - loss: 1.9855 - acc: 0.2017 - val_loss: 1.8187 - val_acc: 0.1833
# Epoch 3/16
# 3000/3000 [==============================] - 21s 7ms/step - loss: 1.8993 - acc: 0.2223 - val_loss: 1.7825 - val_acc: 0.2117
# Epoch 4/16
# 3000/3000 [==============================] - 24s 8ms/step - loss: 1.8354 - acc: 0.2413 - val_loss: 1.7638 - val_acc: 0.2350
# Epoch 5/16
# 3000/3000 [==============================] - 23s 8ms/step - loss: 1.7932 - acc: 0.2567 - val_loss: 1.7422 - val_acc: 0.2200
# Epoch 6/16
# 3000/3000 [==============================] - 28s 9ms/step - loss: 1.7419 - acc: 0.2700 - val_loss: 1.7257 - val_acc: 0.2533
# Epoch 7/16
# 3000/3000 [==============================] - 23s 8ms/step - loss: 1.7400 - acc: 0.2710 - val_loss: 1.7176 - val_acc: 0.2483
# Epoch 8/16
# 3000/3000 [==============================] - 22s 7ms/step - loss: 1.7112 - acc: 0.2793 - val_loss: 1.7063 - val_acc: 0.2483
# Epoch 9/16
# 3000/3000 [==============================] - 24s 8ms/step - loss: 1.6952 - acc: 0.2900 - val_loss: 1.6920 - val_acc: 0.2767
# Epoch 10/16
# 3000/3000 [==============================] - 23s 8ms/step - loss: 1.6835 - acc: 0.2933 - val_loss: 1.6797 - val_acc: 0.2633
# Epoch 11/16
# 3000/3000 [==============================] - 23s 8ms/step - loss: 1.6650 - acc: 0.2907 - val_loss: 1.6763 - val_acc: 0.2783
# Epoch 12/16
# 3000/3000 [==============================] - 23s 8ms/step - loss: 1.6465 - acc: 0.3050 - val_loss: 1.6794 - val_acc: 0.2733
# Epoch 13/16
# 3000/3000 [==============================] - 23s 8ms/step - loss: 1.6426 - acc: 0.3073 - val_loss: 1.6693 - val_acc: 0.3017
# Epoch 14/16
# 3000/3000 [==============================] - 21s 7ms/step - loss: 1.6425 - acc: 0.3090 - val_loss: 1.6589 - val_acc: 0.3083
# Epoch 15/16
# 3000/3000 [==============================] - 22s 7ms/step - loss: 1.6261 - acc: 0.3197 - val_loss: 1.6510 - val_acc: 0.3117
# Epoch 16/16
# 3000/3000 [==============================] - 22s 7ms/step - loss: 1.6222 - acc: 0.3170 - val_loss: 1.6551 - val_acc: 0.3100

# %%
import matplotlib.pyplot as plt
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()
